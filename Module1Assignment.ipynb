# %%
# Answer for 3.1
# There are 3600 seconds in an hour, I calculated this 
# by multiplying 60 * 60 as instructed and printed the variable

hour = 60 * 60
print (hour)
# Out:
# 3600

# %%
# Answer for 3.2
# Renamed variable for product

seconds_per_hour = 60 * 60
print (seconds_per_hour)
# Out:
# 3600

# %%
# Answer for 3.3
# There are 86,400 seconds per day, I calculated this by taking the 
# seconds in an hour and multiplying by 24 hours/day

print (seconds_per_hour * 24)
# Out:
# 86400

# %%
# Answer for 3.4
# Rewrite by taking the seconds in an
# hour and multiplying by 24 hours/day

seconds_per_day = (seconds_per_hour * 24)
print (seconds_per_day)
# Out:
# 86400

# %%
# Answer for 3.5
# 

seconds_per_day / seconds_per_hour
